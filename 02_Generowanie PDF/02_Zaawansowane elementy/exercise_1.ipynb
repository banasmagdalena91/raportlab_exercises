# %% [markdown]
# W pliku **dane.csv** znajdziesz dane kilku uczniów: imię, nazwisko, płeć, rok urodzenia, lista ocen.
#
# Utwórz **jeden** plik `dane.pdf`, w którym każdy z uczniów będzie przedstawiony na osobnej stronie:
#
# ```
# [Uczennica/Uczeń - wybierz jedno, na podstawie kolumny "płeć"] Imię i nazwisko - nagłówek
# Rok urodzenia - normalny tekst
#
# Oceny: - mniejszy nagłówek
# Język Polski - 6
# Język Angielski - 5
# ...
# ```

# %%
import pandas as pd

from reportlab.lib.pagesizes import A4
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Image
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
styles = getSampleStyleSheet()
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont

# %%
data = pd.read_csv('oceny.csv')

# %%
doc = SimpleDocTemplate("oceny w pdfie.pdf",pagesize=A4,
                        rightMargin=72,leftMargin=72,
                        topMargin=72,bottomMargin=18)
story=[]

# %%
data


#for index, row in data.iterrows():
   # print(index)
   # print(row)
    #print(row['Imię'])
    #print(row['Nazwisko'])
# Out:
#         Imię  Nazwisko Płeć  Rok urodzenia  Język Polski  Język Angielski  \
# 0   Karolina     Nowik    K           1990             5                6
# 1     Marcin   Drogosz    M           1990             3                4
# 2      Karol  Kowalski    M           1993             5                5
# 3  Agnieszka     Krupa    K           1993             5                5
# 4    Mariola    Tomala    K           1993             4                5
#
#    Język Niemiecki  Matematyka  Chemia  Fizyka  Biologia  Historia  Geografia
# 0                5           3       4       4         5         5          4
# 1                3           6       5       5         3         3          5
# 2                5           4       3       3         4         5          4
# 3                4           6       6       5         3         5          4
# 4                4           6       4       6         4         4          3

# %%
for index, row in data.iterrows():
        pupilGender = None
        pupilGender = 'Uczennica' if row['Płeć']=='K' else 'Uczeń'
        header_style = ParagraphStyle('header', parent = styles['Title'], fontName="TimesNewRoman", fontSize = 20)
        
        ptext = f"<font>{pupilGender} {row['Imię']} {row['Nazwisko']}</font>"
        story.append(Paragraph(ptext, header_style))
        pageBreak = PageBreak()
        story.append(pageBreak)
        #ptext = f"<font>{row['Rok urodzenia']}</font>
        #story.append
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\reportlab\platypus\paraparser.py in _initial_frag(self, attr, attrMap, bullet)
#    2876             else:
# -> 2877                 frag.fontName, frag.bold, frag.italic = ps2tt(style.fontName)
#    2878                 frag.fontSize = style.fontSize
#
# ~\anaconda3\lib\site-packages\reportlab\lib\fonts.py in ps2tt(psfn)
#      77         return _ps2tt_map[psfn]
# ---> 78     raise ValueError("Can't map determine family/bold/italic for %s" % psfn)
#      79
#
# ValueError: Can't map determine family/bold/italic for timesnewroman
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\reportlab\platypus\paraparser.py in parse(self, text, style)
#    3214         try:
# -> 3215             self.feed(text)
#    3216         except:
#
# ~\anaconda3\lib\html\parser.py in feed(self, data)
#     109         self.rawdata = self.rawdata + data
# --> 110         self.goahead(0)
#     111
#
# ~\anaconda3\lib\html\parser.py in goahead(self, end)
#     169                 if starttagopen.match(rawdata, i): # < + letter
# --> 170                     k = self.parse_starttag(i)
#     171                 elif startswith("</", i):
#
# ~\anaconda3\lib\html\parser.py in parse_starttag(self, i)
#     343         else:
# --> 344             self.handle_starttag(tag, attrs)
#     345             if tag in self.CDATA_CONTENT_ELEMENTS:
#
# ~\anaconda3\lib\site-packages\reportlab\platypus\paraparser.py in handle_starttag(self, tag, attrs)
#    3237         #call it
# -> 3238         start(attrs or {})
#    3239
#
# ~\anaconda3\lib\site-packages\reportlab\platypus\paraparser.py in start_para(self, attr)
#    2903     def start_para(self,attr):
# -> 2904         frag = self._initial_frag(attr,_paraAttrMap)
#    2905         frag.__tag__ = 'para'
#
# ~\anaconda3\lib\site-packages\reportlab\platypus\paraparser.py in _initial_frag(self, attr, attrMap, bullet)
#    2880         except:
# -> 2881             annotateException('error with style name=%s'%style.name)
#    2882         frag.us_lines = []
#
# ~\anaconda3\lib\site-packages\reportlab\lib\utils.py in annotateException(msg, enc, postMsg, sep)
#    1175     t,v,b=sys.exc_info()
# -> 1176     rl_reraise(t,t(sep.join((_ for _ in (msg,str(v),postMsg) if _))),b)
#    1177
#
# ~\anaconda3\lib\site-packages\reportlab\lib\utils.py in rl_reraise(t, v, b)
#     137     if v.__traceback__ is not b:
# --> 138         raise v.with_traceback(b)
#     139     raise v
#
# ~\anaconda3\lib\site-packages\reportlab\platypus\paraparser.py in _initial_frag(self, attr, attrMap, bullet)
#    2876             else:
# -> 2877                 frag.fontName, frag.bold, frag.italic = ps2tt(style.fontName)
#    2878                 frag.fontSize = style.fontSize
#
# ~\anaconda3\lib\site-packages\reportlab\lib\fonts.py in ps2tt(psfn)
#      77         return _ps2tt_map[psfn]
# ---> 78     raise ValueError("Can't map determine family/bold/italic for %s" % psfn)
#      79
#
# ValueError: error with style name=header Can't map determine family/bold/italic for timesnewroman
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33184\322601704.py in <module>
#       5
#       6         ptext = f"<font>{pupilGender} {row['Imię']} {row['Nazwisko']}</font>"
# ----> 7         story.append(Paragraph(ptext, header_style))
#       8         pageBreak = PageBreak()
#       9         story.append(pageBreak)
#
# ~\anaconda3\lib\site-packages\reportlab\platypus\paragraph.py in __init__(self, text, style, bulletText, frags, caseSensitive, encoding)
#    1798         self.caseSensitive = caseSensitive
#    1799         self.encoding = encoding
# -> 1800         self._setup(text, style, bulletText or getattr(style,'bulletText',None), frags, cleanBlockQuotedText)
#    1801
#    1802
#
# ~\anaconda3\lib\site-packages\reportlab\platypus\paragraph.py in _setup(self, text, style, bulletText, frags, cleaner)
#    1819             _parser = ParaParser()
#    1820             _parser.caseSensitive = self.caseSensitive
# -> 1821             style, frags, bulletTextFrags = _parser.parse(text,style)
#    1822             if frags is None:
#    1823                 raise ValueError("xml parser error (%s) in paragraph beginning\n'%s'"\
#
# ~\anaconda3\lib\site-packages\reportlab\platypus\paraparser.py in parse(self, text, style)
#    3215             self.feed(text)
#    3216         except:
# -> 3217             annotateException('\nparagraph text %s caused exception' % ascii(text))
#    3218         return self._complete_parse()
#    3219
#
# ~\anaconda3\lib\site-packages\reportlab\lib\utils.py in annotateException(msg, enc, postMsg, sep)
#    1174     '''add msg to the args of an existing exception'''
#    1175     t,v,b=sys.exc_info()
# -> 1176     rl_reraise(t,t(sep.join((_ for _ in (msg,str(v),postMsg) if _))),b)
#    1177
#    1178 def escapeOnce(data):
#
# ~\anaconda3\lib\site-packages\reportlab\lib\utils.py in rl_reraise(t, v, b)
#     136 def rl_reraise(t, v, b=None):
#     137     if v.__traceback__ is not b:
# --> 138         raise v.with_traceback(b)
#     139     raise v
#     140 def rl_add_builtins(**kwd):
#
# ~\anaconda3\lib\site-packages\reportlab\platypus\paraparser.py in parse(self, text, style)
#    3213             text = u"<para>"+text+u"</para>"
#    3214         try:
# -> 3215             self.feed(text)
#    3216         except:
#    3217             annotateException('\nparagraph text %s caused exception' % ascii(text))
#
# ~\anaconda3\lib\html\parser.py in feed(self, data)
#     108         """
#     109         self.rawdata = self.rawdata + data
# --> 110         self.goahead(0)
#     111
#     112     def close(self):
#
# ~\anaconda3\lib\html\parser.py in goahead(self, end)
#     168             if startswith('<', i):
#     169                 if starttagopen.match(rawdata, i): # < + letter
# --> 170                     k = self.parse_starttag(i)
#     171                 elif startswith("</", i):
#     172                     k = self.parse_endtag(i)
#
# ~\anaconda3\lib\html\parser.py in parse_starttag(self, i)
#     342             self.handle_startendtag(tag, attrs)
#     343         else:
# --> 344             self.handle_starttag(tag, attrs)
#     345             if tag in self.CDATA_CONTENT_ELEMENTS:
#     346                 self.set_cdata_mode(tag)
#
# ~\anaconda3\lib\site-packages\reportlab\platypus\paraparser.py in handle_starttag(self, tag, attrs)
#    3236             start = self.start_unknown
#    3237         #call it
# -> 3238         start(attrs or {})
#    3239
#    3240     def handle_endtag(self, tag):
#
# ~\anaconda3\lib\site-packages\reportlab\platypus\paraparser.py in start_para(self, attr)
#    2902
#    2903     def start_para(self,attr):
# -> 2904         frag = self._initial_frag(attr,_paraAttrMap)
#    2905         frag.__tag__ = 'para'
#    2906         self._stack = [frag]
#
# ~\anaconda3\lib\site-packages\reportlab\platypus\paraparser.py in _initial_frag(self, attr, attrMap, bullet)
#    2879                 frag.textColor = style.textColor
#    2880         except:
# -> 2881             annotateException('error with style name=%s'%style.name)
#    2882         frag.us_lines = []
#    2883         self.nlinks = self.nlines = 0
#
# ~\anaconda3\lib\site-packages\reportlab\lib\utils.py in annotateException(msg, enc, postMsg, sep)
#    1174     '''add msg to the args of an existing exception'''
#    1175     t,v,b=sys.exc_info()
# -> 1176     rl_reraise(t,t(sep.join((_ for _ in (msg,str(v),postMsg) if _))),b)
#    1177
#    1178 def escapeOnce(data):
#
# ~\anaconda3\lib\site-packages\reportlab\lib\utils.py in rl_reraise(t, v, b)
#     136 def rl_reraise(t, v, b=None):
#     137     if v.__traceback__ is not b:
# --> 138         raise v.with_traceback(b)
#     139     raise v
#     140 def rl_add_builtins(**kwd):
#
# ~\anaconda3\lib\site-packages\reportlab\platypus\paraparser.py in _initial_frag(self, attr, attrMap, bullet)
#    2875                 frag.textColor = hasattr(style,'bulletColor') and style.bulletColor or style.textColor
#    2876             else:
# -> 2877                 frag.fontName, frag.bold, frag.italic = ps2tt(style.fontName)
#    2878                 frag.fontSize = style.fontSize
#    2879                 frag.textColor = style.textColor
#
# ~\anaconda3\lib\site-packages\reportlab\lib\fonts.py in ps2tt(psfn)
#      76     if psfn in _ps2tt_map:
#      77         return _ps2tt_map[psfn]
# ---> 78     raise ValueError("Can't map determine family/bold/italic for %s" % psfn)
#      79
#      80 def tt2ps(fn,b,i):
#
# ValueError:
# paragraph text '<para><font>Uczennica Karolina Nowik</font></para>' caused exception error with style name=header Can't map determine family/bold/italic for timesnewroman

# %%
doc.build(Story)
